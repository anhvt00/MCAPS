# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
df = pd.read_csv('hp_pairs.tsv', sep='\t', header=None)
df.columns = ['p1', 'p2', 'label']
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#         p1    p2  label
# 0      709   712      0
# 1      914  1319      0
# 2      238    20      1
# 3      291   110      0
# 4     1416   577      1
# ...    ...   ...    ...
# 2911   867   235      1
# 2912  1104  1409      0
# 2913   610  1357      0
# 2914   626   898      0
# 2915   888   845      0
#
# [2916 rows x 3 columns]

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
train_test = []
for train_index, test_index in skf.split(df[['p1', 'p2']], df['label']):
    train_test.append((train_index, test_index))

for i in range(5):
    train = df.loc[train_test[i][0]]
    test = df.loc[train_test[i][1]]
    train.to_csv(f'train_test/hp_train{i}.tsv', sep='\t', header=None, index=None)
    test.to_csv(f'train_test/hp_test{i}.tsv', sep='\t', header=None, index=None)
